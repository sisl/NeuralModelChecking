# %%
include("tree_utils.jl")
# Out:
# normalize_point_3d (generic function with 1 method)

# %%
prefix = "/scratch/smkatz/pre3dshared/pra1tau35"
sta = shared_treearray(prefix);

# %%
include("viz.jl")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-14227241325251991294\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-4100744195606538875\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n   
# ...

# %%
ax = plot_nadvs_3d(sta, -90.0)
# Out:
# Axis(PGFPlots.Plots.Plot[Command("\\filldraw[fill=blue, draw=black] (87.5,7500.0) rectangle (100.0,8000.0);"), Command("\\filldraw[fill=red, draw=black] (84.375,7875.0) rectangle (87.5,8000.0);"), Command("\\filldraw[fill=red, draw=black] (81.25,7875.0) rectangle (84.375,8000.0);"), Command("\\filldraw[fill=blue, draw=black] (84.375,7750.0) rectangle (87.5,7875.0);"), Command("\\filldraw[fill=blue, draw=black] (81.25,7750.0) rectangle (84.375,7875.0);"), Command("\\filldraw[fill=red, draw=black] (78.125,7875.0) rectangle (81.25,8000.0);"), Command("\\filldraw[fill=red, draw=black] (75.0,7875.0) rectangle (78.125,8000.0);"), Command("\\filldraw[fill=red, draw=black] (78.125,7750.0) rectangle (81.25,7875.0);"), Command("\\filldraw[fill=red, draw=black] (75.0,7750.0) rectangle (78.125,7875.0);"), Command("\\filldraw[fill=blue, draw=black] (81.25,7500.0) rectangle (87.5,7750.0);")  …  Command("\\filldraw[fill=red, draw=black] (-100.0,-625.0) rectangle (-93.75,-500.0);"), Command("\\filld
# ...
